# %% [markdown]
# <a href="https://colab.research.google.com/github/bracealround/CourseraMachineLearning/blob/master/scrapbdprotidin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4
import requests
import os
import pandas as pd
import re
from datetime import timedelta, datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def getNewsFromCategoryAndDate(category, date):
  url = f"https://www.bd-pratidin.com/{category}/{date}"
  page = requests.get(url)
  soup = bs4.BeautifulSoup(page.content,"html.parser").find("div",{"class": "container-left-area col-md-9"})
  newsLinks = []

  for a in soup.findAll("a", {"href": re.compile(r"^[a-z-]+\/\d+\/\d+\/\d+\/\d+$")}):
    newsLinks.append(a["href"])

  return newsLinks

# %%
def getNewsFromLink(link):
  url = f"https://www.bd-pratidin.com/{link}"
  page = requests.get(url)
  soup = bs4.BeautifulSoup(page.content, "html.parser")

  title = soup.find("h1", {"class":"post-title"}).text.strip()
  description = soup.find("meta",{"property":"og:description"})["content"].strip()
  category = link.split("/")[0]
  id = int(link.split("/")[4])
  date = "/".join(link.split("/")[1:4])

  articleSoup = soup.find("article")
  article = ""
  for p in articleSoup.findAll("p"):
    article += p.text

  return {"id": id,
          "title": title, 
          "description": description, 
          "category": category,
          "date": date,
          "article": article}

# %%
def getNewsFromDate(date, save=0, verbose=1):
  url = f"https://www.bd-pratidin.com/archive/{date}"
  page = requests.get(url)
  soup = bs4.BeautifulSoup(page.content, "html.parser").find("div", {"class": "container-left-area printversion col-md-9"})
  categories = set()

  for a in soup.findAll("a", {"href": re.compile(r"^[a-z-]+\/\d+\/\d+\/\d+")}):
    categories.add(a["href"].split("/")[0])
  categories = list(categories)

  if verbose==1:
    print(f"There are {len(categories)} categories.")

  news = []
  for category in categories:
    newsLink = getNewsFromCategoryAndDate(category, date)

    if verbose==1:
      print(f"Downloading {len(newsLink)} news from '{category}' category...")

    for link in newsLink:
      news.append(getNewsFromLink(link))

    if verbose==1:
      print(f"Done!")

  news_df = pd.DataFrame(news)

  if save != 0:
    news_df.to_csv(save, index=False)

  return news_df

# %% [markdown]
# # New section

# %%
def saveNewsFromMultipleDate(days=0, startDate=datetime.today(), filepath="", verbose=1):
  for day in range(days+1):
    date = (startDate - timedelta(days=day)).strftime("%Y/%m/%d")
    filename = "-".join(date.split("/")) + ".csv"
    path = filepath + filename

    if verbose==1:
      print(f"Saving news from {date} in {filename}...")

    getNewsFromDate(date, path, verbose)

    if verbose==1:
      print(f"Saving news from {date} in {filename} is complete.\n")

# %% [markdown]
# filepath = "/content/drive/My Drive/"
# startDate = datetime.today() - timedelta(0)
# days = 0
#
# saveNewsFromMultipleDate(days, startDate, filepath)

# %% [markdown]
# # New section

# %%
filepath = "/content/drive/My Drive/"
startDate = datetime.today() - timedelta(365)
days = 700

saveNewsFromMultipleDate(days, startDate, filepath)
# Out:
# Saving news from 2019/09/12 in 2019-09-12.csv...
# There are 11 categories.
# Downloading 9 news from 'last-page' category...
# Done!
# Downloading 19 news from 'country-village' category...
# Done!
# Downloading 8 news from 'entertainment-news' category...
# Done!
# Downloading 14 news from 'city' category...
# Done!
# Downloading 11 news from 'first-page' category...
# Done!
# Downloading 4 news from 'international' category...
# Done!
# Downloading 5 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 14 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 6 news from 'news' category...
# Done!
# Saving news from 2019/09/12 in 2019-09-12.csv is complete.
#
# Saving news from 2019/09/11 in 2019-09-11.csv...
# There are 1 categories.
# Downloading 0 news from 'first-page' category...
# Done!
# Saving news from 2019/09/11 in 2019-09-11.csv is complete.
#
# Saving news from 2019/09/10 in 2019-09-10.csv...
# There are 12 categories.
# Downloading 20 news from 'last-page' category...
# Done!
# Downloading 22 news from 'country-village' category...
# Done!
# Downloading 7 news from 'entertainment-news' category...
# Done!
# Downloading 18 news from 'city' category...
# Done!
# Downloading 15 news from 'first-page' category...
# Done!
# Downloading 11 news from 'international' category...
# Done!
# Downloading 5 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 14 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 7 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/10 in 2019-09-10.csv is complete.
#
# Saving news from 2019/09/09 in 2019-09-09.csv...
# There are 13 categories.
# Downloading 1 news from 'education' category...
# Done!
# Downloading 19 news from 'last-page' category...
# Done!
# Downloading 21 news from 'country-village' category...
# Done!
# Downloading 6 news from 'entertainment-news' category...
# Done!
# Downloading 23 news from 'city' category...
# Done!
# Downloading 15 news from 'first-page' category...
# Done!
# Downloading 10 news from 'international' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 15 news from 'sport-news' category...
# Done!
# Downloading 7 news from 'rokomari-rommo' category...
# Done!
# Downloading 8 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/09 in 2019-09-09.csv is complete.
#
# Saving news from 2019/09/08 in 2019-09-08.csv...
# There are 11 categories.
# Downloading 17 news from 'last-page' category...
# Done!
# Downloading 30 news from 'country-village' category...
# Done!
# Downloading 9 news from 'entertainment-news' category...
# Done!
# Downloading 13 news from 'city' category...
# Done!
# Downloading 15 news from 'first-page' category...
# Done!
# Downloading 4 news from 'international' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 16 news from 'sport-news' category...
# Done!
# Downloading 5 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/08 in 2019-09-08.csv is complete.
#
# Saving news from 2019/09/07 in 2019-09-07.csv...
# There are 13 categories.
# Downloading 13 news from 'last-page' category...
# Done!
# Downloading 26 news from 'country-village' category...
# Done!
# Downloading 5 news from 'entertainment-news' category...
# Done!
# Downloading 19 news from 'city' category...
# Done!
# Downloading 16 news from 'first-page' category...
# Done!
# Downloading 6 news from 'international' category...
# Done!
# Downloading 6 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 19 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'health' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 11 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/07 in 2019-09-07.csv is complete.
#
# Saving news from 2019/09/06 in 2019-09-06.csv...
# There are 10 categories.
# Downloading 17 news from 'last-page' category...
# Done!
# Downloading 21 news from 'country-village' category...
# Done!
# Downloading 8 news from 'entertainment-news' category...
# Done!
# Downloading 22 news from 'city' category...
# Done!
# Downloading 13 news from 'first-page' category...
# Done!
# Downloading 8 news from 'international' category...
# Done!
# Downloading 5 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 14 news from 'sport-news' category...
# Done!
# Downloading 4 news from 'news' category...
# Done!
# Saving news from 2019/09/06 in 2019-09-06.csv is complete.
#
# Saving news from 2019/09/05 in 2019-09-05.csv...
# There are 9 categories.
# Downloading 15 news from 'last-page' category...
# Done!
# Downloading 23 news from 'country-village' category...
# Done!
# Downloading 7 news from 'entertainment-news' category...
# Done!
# Downloading 14 news from 'first-page' category...
# Done!
# Downloading 5 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 16 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 15 news from 'news' category...
# Done!
# Saving news from 2019/09/05 in 2019-09-05.csv is complete.
#
# Saving news from 2019/09/04 in 2019-09-04.csv...
# There are 13 categories.
# Downloading 11 news from 'last-page' category...
# Done!
# Downloading 26 news from 'country-village' category...
# Done!
# Downloading 4 news from 'entertainment-news' category...
# Done!
# Downloading 17 news from 'city' category...
# Done!
# Downloading 18 news from 'first-page' category...
# Done!
# Downloading 6 news from 'international' category...
# Done!
# Downloading 5 news from 'information-tecnology' category...
# Done!
# Downloading 6 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 16 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 11 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/04 in 2019-09-04.csv is complete.
#
# Saving news from 2019/09/03 in 2019-09-03.csv...
# There are 14 categories.
# Downloading 2 news from 'education' category...
# Done!
# Downloading 12 news from 'last-page' category...
# Done!
# Downloading 24 news from 'country-village' category...
# Done!
# Downloading 5 news from 'entertainment-news' category...
# Done!
# Downloading 17 news from 'city' category...
# Done!
# Downloading 5 news from 'various-city-roundup' category...
# Done!
# Downloading 14 news from 'first-page' category...
# Done!
# Downloading 11 news from 'international' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 19 news from 'sport-news' category...
# Done!
# Downloading 3 news from 'health' category...
# Done!
# Downloading 18 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/03 in 2019-09-03.csv is complete.
#
# Saving news from 2019/09/02 in 2019-09-02.csv...
# There are 13 categories.
# Downloading 24 news from 'last-page' category...
# Done!
# Downloading 23 news from 'country-village' category...
# Done!
# Downloading 6 news from 'entertainment-news' category...
# Done!
# Downloading 19 news from 'city' category...
# Done!
# Downloading 11 news from 'first-page' category...
# Done!
# Downloading 7 news from 'international' category...
# Done!
# Downloading 3 news from 'information-tecnology' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 16 news from 'sport-news' category...
# Done!
# Downloading 7 news from 'rokomari-rommo' category...
# Done!
# Downloading 2 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/02 in 2019-09-02.csv is complete.
#
# Saving news from 2019/09/01 in 2019-09-01.csv...
# There are 13 categories.
# Downloading 2 news from 'education' category...
# Done!
# Downloading 9 news from 'last-page' category...
# Done!
# Downloading 16 news from 'country-village' category...
# Done!
# Downloading 6 news from 'entertainment-news' category...
# Done!
# Downloading 22 news from 'city' category...
# Done!
# Downloading 15 news from 'first-page' category...
# Done!
# Downloading 9 news from 'international' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 19 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 7 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/09/01 in 2019-09-01.csv is complete.
#
# Saving news from 2019/08/31 in 2019-08-31.csv...
# There are 12 categories.
# Downloading 20 news from 'last-page' category...
# Done!
# Downloading 15 news from 'country-village' category...
# Done!
# Downloading 6 news from 'entertainment-news' category...
# Done!
# Downloading 19 news from 'city' category...
# Done!
# Downloading 14 news from 'first-page' category...
# Done!
# Downloading 9 news from 'international' category...
# Done!
# Downloading 5 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 13 news from 'sport-news' category...
# Done!
# Downloading 2 news from 'health' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 5 news from 'news' category...
# Done!
# Saving news from 2019/08/31 in 2019-08-31.csv is complete.
#
# Saving news from 2019/08/30 in 2019-08-30.csv...
# There are 11 categories.
# Downloading 17 news from 'last-page' category...
# Done!
# Downloading 29 news from 'country-village' category...
# Done!
# Downloading 5 news from 'entertainment-news' category...
# Done!
# Downloading 17 news from 'city' category...
# Done!
# Downloading 16 news from 'first-page' category...
# Done!
# Downloading 5 news from 'international' category...
# Done!
# Downloading 4 news from 'rokomari-sahitto' category...
# Done!
# Downloading 4 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 9 news from 'sport-news' category...
# Done!
# Downloading 7 news from 'news' category...
# Done!
# Saving news from 2019/08/30 in 2019-08-30.csv is complete.
#
# Saving news from 2019/08/29 in 2019-08-29.csv...
# There are 12 categories.
# Downloading 17 news from 'last-page' category...
# Done!
# Downloading 22 news from 'country-village' category...
# Done!
# Downloading 4 news from 'entertainment-news' category...
# Done!
# Downloading 16 news from 'city' category...
# Done!
# Downloading 17 news from 'first-page' category...
# Done!
# Downloading 7 news from 'international' category...
# Done!
# Downloading 6 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 15 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 5 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/08/29 in 2019-08-29.csv is complete.
#
# Saving news from 2019/08/28 in 2019-08-28.csv...
# There are 11 categories.
# Downloading 21 news from 'last-page' category...
# Done!
# Downloading 21 news from 'country-village' category...
# Done!
# Downloading 6 news from 'entertainment-news' category...
# Done!
# Downloading 22 news from 'city' category...
# Done!
# Downloading 11 news from 'first-page' category...
# Done!
# Downloading 9 news from 'international' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 13 news from 'sport-news' category...
# Done!
# Downloading 1 news from 'various' category...
# Done!
# Downloading 9 news from 'news' category...
# Done!
# Saving news from 2019/08/28 in 2019-08-28.csv is complete.
#
# Saving news from 2019/08/27 in 2019-08-27.csv...
# There are 13 categories.
# Downloading 21 news from 'last-page' category...
# Done!
# Downloading 21 news from 'country-village' category...
# Done!
# Downloading 7 news from 'entertainment-news' category...
# Done!
# Downloading 16 news from 'city' category...
# Done!
# Downloading 5 news from 'various-city-roundup' category...
# Done!
# Downloading 20 news from 'first-page' category...
# Done!
# Downloading 8 news from 'international' category...
# Done!
# Downloading 5 news from 'information-tecnology' category...
# Done!
# Downloading 6 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 15 news from 'sport-news' category...
# Done!
# Downloading 9 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/08/27 in 2019-08-27.csv is complete.
#
# Saving news from 2019/08/26 in 2019-08-26.csv...
# There are 12 categories.
# Downloading 19 news from 'last-page' category...
# Done!
# Downloading 20 news from 'country-village' category...
# Done!
# Downloading 8 news from 'entertainment-news' category...
# Done!
# Downloading 17 news from 'city' category...
# Done!
# Downloading 14 news from 'first-page' category...
# Done!
# Downloading 8 news from 'international' category...
# Done!
# Downloading 7 news from 'editorial' category...
# Done!
# Downloading 1 news from 'horoscope' category...
# Done!
# Downloading 17 news from 'sport-news' category...
# Done!
# Downloading 7 news from 'rokomari-rommo' category...
# Done!
# Downloading 8 news from 'news' category...
# Done!
# Downloading 1 news from 'money-market-business' category...
# Done!
# Saving news from 2019/08/26 in 2019-08-26.csv is complete.
#
# Saving news from 2019/08/25 in 2019-08-25.csv...
# There are 13 categories.
# Downloading 2 news from 'education' category...
# Done!
# Downloading 16 news from 'last-page' category...
# Done!
# Downloading 23 news from 'country-village' category...
# Done!
# Downloading 7 news from 'entertainment-news' category...
# Done!
# Downloading 20 news from 'city' category...
# Done!
# Downloading 11 news from 'first-page' category...
